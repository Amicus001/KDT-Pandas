# %%
### 성인-복수응답 데이터 다듬어 둔 버전
import pandas as pd
adult_kindDF = pd.read_csv('../DATA/성인_사이버폭력_목격_경험_유형_수_20240119171016.csv') 
adult_kindDF
# Out:
#          특성별(1)        특성별(2)    2022    2022.1    2022.2     2022.3  2022.4
# 0        특성별(1)        특성별(2)  1개 (%)  2~3개 (%)  4~5개 (%)  6개 이상 (%)  평균 (개)
# 1            전체            소계   67.20     29.60      2.70       0.50    1.49
# 2            성별            남성   64.20     33.00      2.40       0.40    1.50
# 3            성별            여성   71.30     24.80      3.20       0.70    1.47
# 4           연령별        19~29세   62.90     34.00      2.30       0.80    1.57
# 5           연령별        30~39세   71.10     26.90      2.00       0.00    1.38
# 6           연령별        40~49세   71.40     23.90      4.70       0.00    1.43
# 7           연령별        50~59세   63.90     36.10      0.00       0.00    1.41
# 8           연령별        60~69세   66.80     22.30      5.50       5.50    1.89
# 9           학력별          초졸이하    0.00    100.00      0.00       0.00    3.00
# 10          학력별            중졸   66.20     33.80      0.00       0.00    1.34
# ...

# %%
#컬럼 이름 바꾸기
adult_kindDF.columns = ['특성1', '특성2', '1개','2-3개', '4-5개', '6개 이상', '평균']

# %%
#'권역별'데이터 삭제
filter = adult_kindDF.loc[41:46]
adult_kindDF.drop(0, inplace = True)
adult_kindDF.drop(index = filter.index,inplace = True)

#Row 이름끼리 묶어서 따로 저장
gender = adult_kindDF[1:4]
age = adult_kindDFF[4:8]
academic_ability = adult_kindDF[10:12]
jobs = adult_kindDF[13:20]
marrige = adult_kindDF[21:23]
average_earn = adult_kindDF[26:33]
howmany_family = adult_kindDF[34:37]
howbig_city = adult_kindDF[47:50]
internet_usage = adult_kindDF[47:50]
prevent_education = adult_kindDF[51:52]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 #'권역별'데이터 삭제
#       2 filter = adult_kindDF.loc[41:46]
# ----> 3 adult_kindDF.drop(0, inplace = True)
#       4 adult_kindDF.drop(index = filter.index,inplace = True)
#       6 #Row 이름끼리 묶어서 따로 저장
#
# File ~\anaconda3\envs\My_38\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...
